# %%
import os
import tensorflow as tf
import numpy as np
import time
import vgg_preprocess

class Vgg16:
    def __init__(self, images):
        self.parameters = [] #在类的初始化时加入全局列表，将所需共享的参数加载到复用类中
        self.images = images
        self.conv_layers()
        self.fc_layers()
        self.probs = tf.nn.softmax(self.fc8) #输出每个属于各个类别的概率值

    def saver(self):
        return tf.train.Saver()

    def load_weights(self, weight_file, sess):
        weights = np.load(weight_file)
        keys = sorted(weights.keys())
        for i, k in enumerate(keys):
            if i not in [30, 31]: #排除不需要载入的层（只保留最后一个全连阶层fc8）
                sess.run(self.parameters[i].assign(weights[k]))
        print("-----weighes loaded-----")

    def conv(self, name, input_data, out_channel, trainable=False):
        in_channel = input_data.get_shape()[-1]
        with tf.variable_scope(name):
            kernel = tf.get_variable("weights", [3, 3, in_channel, out_channel], dtype=tf.float32, trainable=trainable)
            biases = tf.get_variable("biases", [out_channel], dtype=tf.float32, trainable=trainable)
            conv_res = tf.nn.conv2d(input_data, kernel, [1,1,1,1], padding="SAME")
            res = tf.nn.bias_add(conv_res, biases)
            out = tf.nn.relu(res, name=name)
        self.parameters += [kernel, biases] #将卷积层定义的参数（kernel, biases）加入列表
        return out

    def fullconn(self, name, input_data, out_channel, trainable=True):
        shape = input_data.get_shape().as_list()
        if len(shape) == 4:
            size = shape[-3] * shape[-2] * shape[-1] #获得输入数据各个维度的维数
        else:
            size = shape[1]
        input_data_flat = tf.reshape(input_data, [-1,size])
        with tf.variable_scope(name):
            weights = tf.get_variable(name="weights", shape=[size, out_channel], dtype=tf.float32, trainable=trainable)
            biases = tf.get_variable(name="biases", shape=[out_channel], dtype=tf.float32, trainable=trainable)
            res = tf.matmul(input_data_flat, weights)
            out = tf.nn.relu(tf.nn.bias_add(res, biases))
        self.parameters += [weights, biases] #将全连接层定义的参数（weights, biases）加入列表
        return out

    def conv_layers(self):
        #conv1
        self.conv1_1 = self.conv("conv1re_1", self.images, 64, trainable=False)
        self.conv1_2 = self.conv("conv1_2", self.conv1_1, 64, trainable=False)
        self.pool1 = self.maxpool("poolre1", self.conv1_2)
        #conv2
        self.conv2_1 = self.conv("conv2_1", self.pool1, 128, trainable=False)
        self.conv2_2 = self.conv("convwe2_2", self.conv2_1, 128, trainable=False)
        self.pool2 = self.maxpool("pool2", self.conv2_2)
        #conv3
        self.conv3_1 = self.conv("conv3_1", self.pool2, 256, trainable=False)
        self.conv3_2 = self.conv("convrwe3_2", self.conv3_1, 256, trainable=False)
        self.conv3_3 = self.conv("convrwe3_3", self.conv3_2, 256, trainable=False)
        self.pool3 = self.maxpool("poolre3", self.conv3_3)
        #conv4
        self.conv4_1 = self.conv("conv4_1", self.pool3, 512, trainable=False)
        self.conv4_2 = self.conv("convrwe4_2", self.conv4_1, 512, trainable=False)
        self.conv4_3 = self.conv("convrwe4_3", self.conv4_2, 512, trainable=False)
        self.pool4 = self.maxpool("pool4", self.conv4_3)
        #conv5
        self.conv5_1 = self.conv("conv5_1", self.pool4, 512, trainable=False)
        self.conv5_2 = self.conv("convrwe5_2", self.conv5_1, 512, trainable=False)
        self.conv5_3 = self.conv("conv5_3", self.conv5_2, 512, trainable=False)
        self.pool5 = self.maxpool("poolrwe5", self.conv5_3)

    n_class = 2
    def fc_layers(self):
        global n_class
        self.fc6 = self.fullconn("fc1", self.pool5, 4096, trainable=False)
        self.fc7 = self.fullconn("fc2", self.fc6, 4096, trainable=False)
        self.fc8 = self.fullconn("fc3", self.fc7, self.n_class, trainable=True)

    def maxpool(self, name, input_data):
        out = tf.nn.max_pool(input_data, [1,2,2,1], [1,2,2,1], padding="SAME", name=name)
        return out

def get_file(file_dir):
    '''
    Args:
        file_dir: file directory
    Returns:
        list of images and labels
    '''
    cats = []
    dogs = []
    image_list = []
    label_list = []

    for root, sub_folders, files in os.walk(file_dir): #遍历file_dir下的所有目录和文件
        for name in files: #images中保存的是file_dir下各级子文件夹下的文件(完整路径)
            image_list.append(os.path.join(root, name))
            category = name.split(sep='.') #文件名按.分割
            if category[0] == 'cat': #如果是cat，标签为0，dog为1
                cats.append(os.path.join(root, name))
                label_list.append(0)
            elif category[0] == 'dog':
                dogs.append(os.path.join(root, name))
                label_list.append(1)
            else:
                print("unrecognized category")
        #for file in sub_folders: #temp中保存的是file_dir下各级子文件夹(完整路径)
        #    temp.append(os.path.join(root, file))
    print('There are %d cats\nThere are %d dogs' %(len(cats), len(dogs))) #打印猫和狗的数量
    print("image_list is")
    #print(image_list)
    print("label_list is")
    #print(label_list)
    label_list = [int(i) for i in label_list] #将label_list中的数据类型转为int型
    #print("label_list is")
    #print(label_list)
    
    return image_list, label_list

#get_file(r"E:\shiyan")
#get_file(r"E:\AI-learn\kaggle\train")

def get_batch(image_list, label_list, image_width, image_height, batch_size, capacity): #通过读取列表来批量载入图片以及对应标签
    image = tf.cast(image_list, tf.string) #将image_list的数据格式转化成string
    label = tf.cast(label_list, tf.int32) #将label_list的数据格式转化成int32
    input_queue = tf.train.slice_input_producer([image, label]) #每次从一个tensor列表中按顺序或者随机抽取出一个tensor放入文件名队列
    label = input_queue[1]
    image_contents = tf.read_file(input_queue[0]) #读取图片
    
    image = tf.image.decode_jpeg(image_contents, channels=3) #解码JPEG格式图像
    image = vgg_preprocess.preprocess_for_train(image, 224, 224)
    image_batch, label_batch = tf.train.batch([image, label], batch_size=batch_size, num_threads=64, capacity=capacity)
    label_batch = tf.reshape(label_batch, [batch_size])
    
    return image_batch, label_batch

def onehot(labels):
    n_sample = len(labels)
    n_class = max(labels)+1
    onehot_labels = np.zeros((n_sample, n_class)) #n_sample行, n_class列
    onehot_labels[np.arange(n_sample), labels] = 1 #对应的行,对应的列赋为1,很巧妙的方法

    return onehot_labels

tf.reset_default_graph()

start_time = time.time() #计算每次迭代的时间
batch_size =32 #批处理样本的大小
capacity = 256 #内存中存储的最大数据容量
means = [123.68, 116.799, 103.939] #VGG训练时图像预处理所减均值(RGB三通道)

image_list, label_list = get_file(r"E:\AI-learn\kaggle\train") #获取图像列表和标签列表
#image_list, label_list = get_file(r"E:\AI-learn\train") #获取图像列表和标签列表
image_batch, label_batch = get_batch(image_list, label_list, 224, 224, batch_size, capacity) #通过读取列表来批量载入图片及标签
x = tf.placeholder(tf.float32, [None, 224, 224, 3])
y = tf.placeholder(tf.int32, [None, 2]) #对"猫"和狗两个类别进行判定

vgg = Vgg16(x)

fc8_finetuining = vgg.probs
loss_function = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=fc8_finetuining, labels=y)) #损失函数
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001).minimize(loss_function)

sess = tf.Session()
sess.run(tf.global_variables_initializer())
vgg.load_weights(r"E:\AI-learn\vgg16_weights.npz", sess) #通过npz格式的文件获取Vgg的相应权重参数,从而实现权重复用
saver = tf.train.Saver()

#启动线程
coord = tf.train.Coordinator() #使用协调器来管理线程
threads = tf.train.start_queue_runners(coord=coord, sess=sess)

epoch_start_time = time.time()
for i in range(1000):
    images, labels = sess.run([image_batch, label_batch])
    labels = onehot(labels) #用one-hot形式对标签进行编码    
    sess.run(optimizer, feed_dict={x:images, y:labels})
    loss = sess.run(loss_function, feed_dict={x:images, y:labels})
    print("Epoch %d, the loss is %f" %(i, loss))
    epoch_end_time = time.time()
    print("Current epoch takes: ", (epoch_end_time-epoch_start_time))
    epoch_start_time = epoch_end_time

    if (i+1)%500 == 0:
        saver.save(sess, os.path.join("./model/", "epoch_{:06d}.ckpt".format(i)))
    print("-------Epoch %d is finished.-------" %i)

saver.save(sess, "./model/")
print("Optimization Finished.")

duration = time.time() - start_time
print("The train process takes:", "{:.2f}".format(duration))

#关闭线程
coord.request_stop() #通知其他线程关闭
coord.join(threads) #等待其他线程结束,其他所有线程关闭之后,这一函数才能返回
# Out:
# There are 12500 cats
# There are 12500 dogs
# image_list is
# label_list is
# -----weighes loaded-----
# Epoch 0, the loss is 0.683989
# Current epoch takes:  49.4779999256134
# -------Epoch 0 is finished.-------
# Epoch 1, the loss is 0.715494
# Current epoch takes:  27.31000018119812
# -------Epoch 1 is finished.-------
# Epoch 2, the loss is 0.716406
# Current epoch takes:  26.90499997138977
# -------Epoch 2 is finished.-------
# Epoch 3, the loss is 0.724763
# Current epoch takes:  27.621000051498413
# -------Epoch 3 is finished.-------
# Epoch 4, the loss is 0.669271
# Current epoch takes:  26.84999990463257
# -------Epoch 4 is finished.-------
# Epoch 5, the loss is 0.640444
# Current epoch takes:  27.134999990463257
# -------Epoch 5 is finished.-------
# Epoch 6, the loss is 0.666984
# Current epoch takes:  27.869999885559082
# -------Epoch 6 is finished.-------
# Epoch 7, the loss is 0.674446
# Current epoch takes:  27.633000135421753
# -------Epoch 7 is finished.-------
# Epoch 8, the loss is 0.697619
# Current epoch takes:  27.634000062942505
# -------Epoch 8 is finished.-------
# Epoch 9, the loss is 0.715928
# Current epoch takes:  27.133999824523926
# -------Epoch 9 is finished.-------
# Epoch 10, the loss is 0.662490
# Current epoch takes:  27.073000192642212
# -------Epoch 10 is finished.-------
# Epoch 11, the loss is 0.637913
# Current epoch takes:  27.536999940872192
# -------Epoch 11 is finished.-------
# Epoch 12, the loss is 0.639102
# Current epoch takes:  27.44599986076355
# -------Epoch 12 is finished.-------
# Epoch 13, the loss is 0.625828
# Current epoch takes:  27.032000064849854
# -------Epoch 13 is finished.-------
# Epoch 14, the loss is 0.594201
# Current epoch takes:  27.871000051498413
# -------Epoch 14 is finished.-------
# Epoch 15, the loss is 0.636703
# Current epoch takes:  26.996999979019165
# -------Epoch 15 is finished.-------
# Epoch 16, the loss is 0.634467
# Current epoch takes:  27.30399990081787
# -------Epoch 16 is finished.-------
# Epoch 17, the loss is 0.659924
# Current epoch takes:  27.248000144958496
# -------Epoch 17 is finished.-------
# Epoch 18, the loss is 0.653998
# Current epoch takes:  27.33399987220764
# -------Epoch 18 is finished.-------
# Epoch 19, the loss is 0.630529
# Current epoch takes:  27.305999994277954
# -------Epoch 19 is finished.-------
# Epoch 20, the loss is 0.600522
# Current epoch takes:  26.973000049591064
# -------Epoch 20 is finished.-------
# Epoch 21, the loss is 0.615456
# Current epoch takes:  26.710999965667725
# -------Epoch 21 is finished.-------
# Epoch 22, the loss is 0.617277
# Current epoch takes:  27.427000045776367
# -------Epoch 22 is finished.-------
# Epoch 23, the loss is 0.631185
# Current epoch takes:  26.802000045776367
# -------Epoch 23 is finished.-------
# Epoch 24, the loss is 0.610190
# Current epoch takes:  27.246000051498413
# -------Epoch 24 is finished.-------
# Epoch 25, the loss is 0.604169
# Current epoch takes:  27.48799991607666
# -------Epoch 25 is finished.-------
# Epoch 26, the loss is 0.648120
# Current epoch takes:  27.147000074386597
# -------Epoch 26 is finished.-------
# Epoch 27, the loss is 0.610714
# Current epoch takes:  27.30999994277954
# -------Epoch 27 is finished.-------
# Epoch 28, the loss is 0.579419
# Current epoch takes:  27.41000008583069
# -------Epoch 28 is finished.-------
# Epoch 29, the loss is 0.586584
# Current epoch takes:  28.413999795913696
# -------Epoch 29 is finished.-------
# Epoch 30, the loss is 0.612933
# Current epoch takes:  28.527000188827515
# -------Epoch 30 is finished.-------
# Epoch 31, the loss is 0.596411
# Current epoch takes:  27.64199995994568
# -------Epoch 31 is finished.-------
# Epoch 32, the loss is 0.584532
# Current epoch takes:  27.32099986076355
# -------Epoch 32 is finished.-------
# Epoch 33, the loss is 0.621897
# Current epoch takes:  26.993000030517578
# -------Epoch 33 is finished.-------
# Epoch 34, the loss is 0.581922
# Current epoch takes:  26.86899995803833
# -------Epoch 34 is finished.-------
# Epoch 35, the loss is 0.582820
# Current epoch takes:  26.972000122070312
# -------Epoch 35 is finished.-------
# Epoch 36, the loss is 0.591768
# Current epoch takes:  27.11299991607666
# -------Epoch 36 is finished.-------
# Epoch 37, the loss is 0.573143
# Current epoch takes:  27.01699995994568
# -------Epoch 37 is finished.-------
# Epoch 38, the loss is 0.609375
# Current epoch takes:  26.90400004386902
# -------Epoch 38 is finished.-------
# Epoch 39, the loss is 0.570317
# Current epoch takes:  26.920000076293945
# -------Epoch 39 is finished.-------
# Epoch 40, the loss is 0.587740
# Current epoch takes:  27.168999910354614
# -------Epoch 40 is finished.-------
# Epoch 41, the loss is 0.545985
# Current epoch takes:  27.152000188827515
# -------Epoch 41 is finished.-------
# Epoch 42, the loss is 0.572149
# Current epoch takes:  26.783999919891357
# -------Epoch 42 is finished.-------
# Epoch 43, the loss is 0.559595
# Current epoch takes:  26.874000072479248
# -------Epoch 43 is finished.-------
# Epoch 44, the loss is 0.536303
# Current epoch takes:  27.12399983406067
# -------Epoch 44 is finished.-------
# Epoch 45, the loss is 0.572767
# Current epoch takes:  26.78500008583069
# -------Epoch 45 is finished.-------
# Epoch 46, the loss is 0.581666
# Current epoch takes:  26.700999975204468
# -------Epoch 46 is finished.-------
# Epoch 47, the loss is 0.560344
# Current epoch takes:  26.94600009918213
# -------Epoch 47 is finished.-------
# Epoch 48, the loss is 0.595375
# Current epoch takes:  27.317999839782715
# -------Epoch 48 is finished.-------
# Epoch 49, the loss is 0.557136
# Current epoch takes:  26.871000051498413
# -------Epoch 49 is finished.-------
# Epoch 50, the loss is 0.554544
# Current epoch takes:  26.950999975204468
# -------Epoch 50 is finished.-------
# Epoch 51, the loss is 0.555301
# Current epoch takes:  26.67900013923645
# -------Epoch 51 is finished.-------
# Epoch 52, the loss is 0.505567
# Current epoch takes:  26.866999864578247
# -------Epoch 52 is finished.-------
# Epoch 53, the loss is 0.561281
# Current epoch takes:  27.532999992370605
# -------Epoch 53 is finished.-------
# Epoch 54, the loss is 0.516064
# Current epoch takes:  26.742000102996826
# -------Epoch 54 is finished.-------
# Epoch 55, the loss is 0.509096
# Current epoch takes:  26.6489999294281
# -------Epoch 55 is finished.-------
# Epoch 56, the loss is 0.558053
# Current epoch takes:  26.881999969482422
# -------Epoch 56 is finished.-------
# Epoch 57, the loss is 0.486734
# Current epoch takes:  26.903000116348267
# -------Epoch 57 is finished.-------
# Epoch 58, the loss is 0.507696
# Current epoch takes:  26.98199987411499
# -------Epoch 58 is finished.-------
# Epoch 59, the loss is 0.458177
# Current epoch takes:  26.630000114440918
# -------Epoch 59 is finished.-------
# Epoch 60, the loss is 0.508260
# Current epoch takes:  26.43400001525879
# -------Epoch 60 is finished.-------
# Epoch 61, the loss is 0.547915
# Current epoch takes:  26.73799991607666
# -------Epoch 61 is finished.-------
# Epoch 62, the loss is 0.484742
# Current epoch takes:  26.611000061035156
# -------Epoch 62 is finished.-------
# Epoch 63, the loss is 0.448923
# Current epoch takes:  26.5939998626709
# -------Epoch 63 is finished.-------
# Epoch 64, the loss is 0.549271
# Current epoch takes:  26.937999963760376
# -------Epoch 64 is finished.-------
# Epoch 65, the loss is 0.502772
# Current epoch takes:  26.777000188827515
# -------Epoch 65 is finished.-------
# Epoch 66, the loss is 0.501754
# Current epoch takes:  26.842000007629395
# -------Epoch 66 is finished.-------
# Epoch 67, the loss is 0.470686
# Current epoch takes:  26.863999843597412
# -------Epoch 67 is finished.-------
# Epoch 68, the loss is 0.588959
# Current epoch takes:  26.669000148773193
# -------Epoch 68 is finished.-------
# Epoch 69, the loss is 0.504431
# Current epoch takes:  26.454999923706055
# -------Epoch 69 is finished.-------
# Epoch 70, the loss is 0.483695
# Current epoch takes:  26.674000024795532
# -------Epoch 70 is finished.-------
# Epoch 71, the loss is 0.456506
# Current epoch takes:  26.734999895095825
# -------Epoch 71 is finished.-------
# Epoch 72, the loss is 0.534120
# Current epoch takes:  26.86400008201599
# -------Epoch 72 is finished.-------
# Epoch 73, the loss is 0.535002
# Current epoch takes:  26.907999992370605
# -------Epoch 73 is finished.-------
# Epoch 74, the loss is 0.464639
# Current epoch takes:  26.58999991416931
# -------Epoch 74 is finished.-------
# Epoch 75, the loss is 0.428983
# Current epoch takes:  26.19099998474121
# -------Epoch 75 is finished.-------
# Epoch 76, the loss is 0.451591
# Current epoch takes:  26.722000122070312
# -------Epoch 76 is finished.-------
# Epoch 77, the loss is 0.431910
# Current epoch takes:  26.734999895095825
# -------Epoch 77 is finished.-------
# Epoch 78, the loss is 0.526961
# Current epoch takes:  26.41700005531311
# -------Epoch 78 is finished.-------
# Epoch 79, the loss is 0.417348
# Current epoch takes:  26.707000017166138
# -------Epoch 79 is finished.-------
# Epoch 80, the loss is 0.524948
# Current epoch takes:  26.683000087738037
# -------Epoch 80 is finished.-------
# Epoch 81, the loss is 0.500894
# Current epoch takes:  26.412999868392944
# -------Epoch 81 is finished.-------
# Epoch 82, the loss is 0.441509
# Current epoch takes:  26.36300015449524
# -------Epoch 82 is finished.-------
# Epoch 83, the loss is 0.414385
# Current epoch takes:  26.192999839782715
# -------Epoch 83 is finished.-------
# Epoch 84, the loss is 0.429854
# Current epoch takes:  26.945000171661377
# -------Epoch 84 is finished.-------
# Epoch 85, the loss is 0.435577
# Current epoch takes:  26.7739999294281
# -------Epoch 85 is finished.-------
# Epoch 86, the loss is 0.452979
# Current epoch takes:  26.717000007629395
# -------Epoch 86 is finished.-------
# Epoch 87, the loss is 0.444606
# Current epoch takes:  26.560999870300293
# -------Epoch 87 is finished.-------
# Epoch 88, the loss is 0.437923
# Current epoch takes:  26.371999979019165
# -------Epoch 88 is finished.-------
# Epoch 89, the loss is 0.468261
# Current epoch takes:  26.139000177383423
# -------Epoch 89 is finished.-------
# Epoch 90, the loss is 0.408309
# Current epoch takes:  26.536999940872192
# -------Epoch 90 is finished.-------
# Epoch 91, the loss is 0.443279
# Current epoch takes:  26.282000064849854
# -------Epoch 91 is finished.-------
# Epoch 92, the loss is 0.457270
# Current epoch takes:  26.406999826431274
# -------Epoch 92 is finished.-------
# Epoch 93, the loss is 0.416531
# Current epoch takes:  26.473000049591064
# -------Epoch 93 is finished.-------
# Epoch 94, the loss is 0.455453
# Current epoch takes:  26.722000122070312
# -------Epoch 94 is finished.-------
# Epoch 95, the loss is 0.441991
# Current epoch takes:  26.39299988746643
# -------Epoch 95 is finished.-------
# Epoch 96, the loss is 0.440656
# Current epoch takes:  26.805000066757202
# -------Epoch 96 is finished.-------
# Epoch 97, the loss is 0.465055
# Current epoch takes:  26.80900001525879
# -------Epoch 97 is finished.-------
# Epoch 98, the loss is 0.438684
# Current epoch takes:  26.437000036239624
# -------Epoch 98 is finished.-------
# Epoch 99, the loss is 0.445411
# Current epoch takes:  26.429999828338623
# -------Epoch 99 is finished.-------
# Epoch 100, the loss is 0.407203
# Current epoch takes:  26.641000032424927
# -------Epoch 100 is finished.-------
# Epoch 101, the loss is 0.467346
# Current epoch takes:  26.67900013923645
# -------Epoch 101 is finished.-------
# Epoch 102, the loss is 0.453799
# Current epoch takes:  26.485999822616577
# -------Epoch 102 is finished.-------
# Epoch 103, the loss is 0.448560
# Current epoch takes:  26.686000108718872
# -------Epoch 103 is finished.-------
# Epoch 104, the loss is 0.411720
# Current epoch takes:  26.716000080108643
# -------Epoch 104 is finished.-------
# Epoch 105, the loss is 0.453230
# Current epoch takes:  26.365999937057495
# -------Epoch 105 is finished.-------
# Epoch 106, the loss is 0.387717
# Current epoch takes:  26.506999969482422
# -------Epoch 106 is finished.-------
# Epoch 107, the loss is 0.437147
# Current epoch takes:  26.674000024795532
# -------Epoch 107 is finished.-------
# Epoch 108, the loss is 0.488584
# Current epoch takes:  26.86899995803833
# -------Epoch 108 is finished.-------
# Epoch 109, the loss is 0.412111
# Current epoch takes:  26.960999965667725
# -------Epoch 109 is finished.-------
# Epoch 110, the loss is 0.439635
# Current epoch takes:  26.661999940872192
# -------Epoch 110 is finished.-------
# Epoch 111, the loss is 0.432176
# Current epoch takes:  26.16800022125244
# -------Epoch 111 is finished.-------
# Epoch 112, the loss is 0.424234
# Current epoch takes:  26.508999824523926
# -------Epoch 112 is finished.-------
# Epoch 113, the loss is 0.428626
# Current epoch takes:  26.5310001373291
# -------Epoch 113 is finished.-------
# Epoch 114, the loss is 0.425198
# Current epoch takes:  26.282999992370605
# -------Epoch 114 is finished.-------
# Epoch 115, the loss is 0.460147
# Current epoch takes:  26.598000049591064
# -------Epoch 115 is finished.-------
# Epoch 116, the loss is 0.489632
# Current epoch takes:  26.823999881744385
# -------Epoch 116 is finished.-------
# Epoch 117, the loss is 0.409015
# Current epoch takes:  26.367000102996826
# -------Epoch 117 is finished.-------
# Epoch 118, the loss is 0.409695
# Current epoch takes:  26.353999853134155
# -------Epoch 118 is finished.-------
# Epoch 119, the loss is 0.397804
# Current epoch takes:  26.788000106811523
# -------Epoch 119 is finished.-------
# Epoch 120, the loss is 0.447438
# Current epoch takes:  26.651000022888184
# -------Epoch 120 is finished.-------
# Epoch 121, the loss is 0.428151
# Current epoch takes:  26.628000020980835
# -------Epoch 121 is finished.-------
# Epoch 122, the loss is 0.428532
# Current epoch takes:  26.467999935150146
# -------Epoch 122 is finished.-------
# Epoch 123, the loss is 0.372994
# Current epoch takes:  26.641000032424927
# -------Epoch 123 is finished.-------
# Epoch 124, the loss is 0.463878
# Current epoch takes:  26.582000017166138
# -------Epoch 124 is finished.-------
# Epoch 125, the loss is 0.412852
# Current epoch takes:  26.33799982070923
# -------Epoch 125 is finished.-------
# Epoch 126, the loss is 0.417386
# Current epoch takes:  26.38100004196167
# -------Epoch 126 is finished.-------
# Epoch 127, the loss is 0.480647
# Current epoch takes:  26.624000072479248
# -------Epoch 127 is finished.-------
# Epoch 128, the loss is 0.407476
# Current epoch takes:  26.675999879837036
# -------Epoch 128 is finished.-------
# Epoch 129, the loss is 0.422042
# Current epoch takes:  26.31599998474121
# -------Epoch 129 is finished.-------
# Epoch 130, the loss is 0.364491
# Current epoch takes:  26.98800015449524
# -------Epoch 130 is finished.-------
# Epoch 131, the loss is 0.425562
# Current epoch takes:  27.48199987411499
# -------Epoch 131 is finished.-------
# Epoch 132, the loss is 0.356769
# Current epoch takes:  26.278000116348267
# -------Epoch 132 is finished.-------
# Epoch 133, the loss is 0.393666
# Current epoch takes:  26.3989999294281
# -------Epoch 133 is finished.-------
# Epoch 134, the loss is 0.474044
# Current epoch takes:  26.421000003814697
# -------Epoch 134 is finished.-------
# Epoch 135, the loss is 0.418135
# Current epoch takes:  26.22699999809265
# -------Epoch 135 is finished.-------
# Epoch 136, the loss is 0.415537
# Current epoch takes:  26.390000104904175
# -------Epoch 136 is finished.-------
# Epoch 137, the loss is 0.430417
# Current epoch takes:  26.41100001335144
# -------Epoch 137 is finished.-------
# Epoch 138, the loss is 0.435155
# Current epoch takes:  26.441999912261963
# -------Epoch 138 is finished.-------
# Epoch 139, the loss is 0.406180
# Current epoch takes:  26.51699995994568
# -------Epoch 139 is finished.-------
# Epoch 140, the loss is 0.390128
# Current epoch takes:  26.278000116348267
# -------Epoch 140 is finished.-------
# Epoch 141, the loss is 0.420749
# Current epoch takes:  26.503999948501587
# -------Epoch 141 is finished.-------
# Epoch 142, the loss is 0.442081
# Current epoch takes:  26.414000034332275
# -------Epoch 142 is finished.-------
# Epoch 143, the loss is 0.411171
# Current epoch takes:  26.359999895095825
# -------Epoch 143 is finished.-------
# Epoch 144, the loss is 0.381568
# Current epoch takes:  26.04100012779236
# -------Epoch 144 is finished.-------
# Epoch 145, the loss is 0.472080
# Current epoch takes:  26.484999895095825
# -------Epoch 145 is finished.-------
# Epoch 146, the loss is 0.403490
# Current epoch takes:  26.52300000190735
# -------Epoch 146 is finished.-------
# Epoch 147, the loss is 0.398748
# Current epoch takes:  26.439000129699707
# -------Epoch 147 is finished.-------
# Epoch 148, the loss is 0.435666
# Current epoch takes:  26.181999921798706
# -------Epoch 148 is finished.-------
# Epoch 149, the loss is 0.394451
# Current epoch takes:  26.483999967575073
# -------Epoch 149 is finished.-------
# Epoch 150, the loss is 0.415519
# Current epoch takes:  26.35599994659424
# -------Epoch 150 is finished.-------
# Epoch 151, the loss is 0.396733
# Current epoch takes:  26.825999975204468
# -------Epoch 151 is finished.-------
# Epoch 152, the loss is 0.379927
# Current epoch takes:  26.484000205993652
# -------Epoch 152 is finished.-------
# Epoch 153, the loss is 0.424483
# Current epoch takes:  26.567999839782715
# -------Epoch 153 is finished.-------
# Epoch 154, the loss is 0.415315
# Current epoch takes:  26.625
# -------Epoch 154 is finished.-------
# Epoch 155, the loss is 0.398868
# Current epoch takes:  26.80299997329712
# -------Epoch 155 is finished.-------
# Epoch 156, the loss is 0.425509
# Current epoch takes:  26.638000011444092
# -------Epoch 156 is finished.-------
# Epoch 157, the loss is 0.386606
# Current epoch takes:  26.115000009536743
# -------Epoch 157 is finished.-------
# Epoch 158, the loss is 0.380777
# Current epoch takes:  26.475000143051147
# -------Epoch 158 is finished.-------
# Epoch 159, the loss is 0.372300
# Current epoch takes:  26.61299991607666
# -------Epoch 159 is finished.-------
# Epoch 160, the loss is 0.429308
# Current epoch takes:  26.64199995994568
# -------Epoch 160 is finished.-------
# Epoch 161, the loss is 0.460458
# Current epoch takes:  26.235000133514404
# -------Epoch 161 is finished.-------
# Epoch 162, the loss is 0.443266
# Current epoch takes:  26.41100001335144
# -------Epoch 162 is finished.-------
# Epoch 163, the loss is 0.445405
# Current epoch takes:  26.658999919891357
# -------Epoch 163 is finished.-------
# Epoch 164, the loss is 0.425870
# Current epoch takes:  26.516000032424927
# -------Epoch 164 is finished.-------
# Epoch 165, the loss is 0.432847
# Current epoch takes:  26.485999822616577
# -------Epoch 165 is finished.-------
# Epoch 166, the loss is 0.419644
# Current epoch takes:  26.53600001335144
# -------Epoch 166 is finished.-------
# Epoch 167, the loss is 0.350251
# Current epoch takes:  26.758000135421753
# -------Epoch 167 is finished.-------
# Epoch 168, the loss is 0.381542
# Current epoch takes:  26.28600001335144
# -------Epoch 168 is finished.-------
# Epoch 169, the loss is 0.385285
# Current epoch takes:  26.61299991607666
# -------Epoch 169 is finished.-------
# Epoch 170, the loss is 0.346756
# Current epoch takes:  26.433000087738037
# -------Epoch 170 is finished.-------
# Epoch 171, the loss is 0.499854
# Current epoch takes:  26.293999910354614
# -------Epoch 171 is finished.-------
# Epoch 172, the loss is 0.417933
# Current epoch takes:  26.319000005722046
# -------Epoch 172 is finished.-------
# Epoch 173, the loss is 0.416255
# Current epoch takes:  26.490999937057495
# -------Epoch 173 is finished.-------
# Epoch 174, the loss is 0.431106
# Current epoch takes:  26.52900004386902
# -------Epoch 174 is finished.-------
# Epoch 175, the loss is 0.394430
# Current epoch takes:  26.69099998474121
# -------Epoch 175 is finished.-------
# Epoch 176, the loss is 0.379565
# Current epoch takes:  26.641000032424927
# -------Epoch 176 is finished.-------
# Epoch 177, the loss is 0.448388
# Current epoch takes:  26.86400008201599
# -------Epoch 177 is finished.-------
# Epoch 178, the loss is 0.462435
# Current epoch takes:  26.240000009536743
# -------Epoch 178 is finished.-------
# Epoch 179, the loss is 0.386597
# Current epoch takes:  26.35599994659424
# -------Epoch 179 is finished.-------
# Epoch 180, the loss is 0.376379
# Current epoch takes:  26.395999908447266
# -------Epoch 180 is finished.-------
# Epoch 181, the loss is 0.422136
# Current epoch takes:  26.198000192642212
# -------Epoch 181 is finished.-------
# Epoch 182, the loss is 0.411909
# Current epoch takes:  26.17799997329712
# -------Epoch 182 is finished.-------
# Epoch 183, the loss is 0.380606
# Current epoch takes:  26.191999912261963
# -------Epoch 183 is finished.-------
# Epoch 184, the loss is 0.415540
# Current epoch takes:  26.361000061035156
# -------Epoch 184 is finished.-------
# Epoch 185, the loss is 0.449120
# Current epoch takes:  26.509999990463257
# -------Epoch 185 is finished.-------
# Epoch 186, the loss is 0.431044
# Current epoch takes:  26.155999898910522
# -------Epoch 186 is finished.-------
# Epoch 187, the loss is 0.393563
# Current epoch takes:  26.453999996185303
# -------Epoch 187 is finished.-------
# Epoch 188, the loss is 0.427325
# Current epoch takes:  26.37000012397766
# -------Epoch 188 is finished.-------
# Epoch 189, the loss is 0.428922
# Current epoch takes:  26.289000034332275
# -------Epoch 189 is finished.-------
# Epoch 190, the loss is 0.360293
# Current epoch takes:  26.28499984741211
# -------Epoch 190 is finished.-------
# Epoch 191, the loss is 0.441283
# Current epoch takes:  26.002000093460083
# -------Epoch 191 is finished.-------
# Epoch 192, the loss is 0.410234
# Current epoch takes:  26.437999963760376
# -------Epoch 192 is finished.-------
# Epoch 193, the loss is 0.370168
# Current epoch takes:  26.223000049591064
# -------Epoch 193 is finished.-------
# Epoch 194, the loss is 0.416160
# Current epoch takes:  26.378000020980835
# -------Epoch 194 is finished.-------
# Epoch 195, the loss is 0.422265
# Current epoch takes:  26.080999851226807
# -------Epoch 195 is finished.-------
# Epoch 196, the loss is 0.409619
# Current epoch takes:  26.506999969482422
# -------Epoch 196 is finished.-------
# Epoch 197, the loss is 0.377371
# Current epoch takes:  26.73900008201599
# -------Epoch 197 is finished.-------
# Epoch 198, the loss is 0.377464
# Current epoch takes:  26.735000133514404
# -------Epoch 198 is finished.-------
# Epoch 199, the loss is 0.416094
# Current epoch takes:  26.971999883651733
# -------Epoch 199 is finished.-------
# Epoch 200, the loss is 0.450068
# Current epoch takes:  28.55900001525879
# -------Epoch 200 is finished.-------
# Epoch 201, the loss is 0.409851
# Current epoch takes:  26.50499987602234
# -------Epoch 201 is finished.-------
# Epoch 202, the loss is 0.390754
# Current epoch takes:  26.683000087738037
# -------Epoch 202 is finished.-------
# Epoch 203, the loss is 0.431413
# Current epoch takes:  26.51099991798401
# -------Epoch 203 is finished.-------
# Epoch 204, the loss is 0.408802
# Current epoch takes:  26.671000003814697
# -------Epoch 204 is finished.-------
# Epoch 205, the loss is 0.419507
# Current epoch takes:  26.611999988555908
# -------Epoch 205 is finished.-------
# Epoch 206, the loss is 0.394115
# Current epoch takes:  26.264000177383423
# -------Epoch 206 is finished.-------
# Epoch 207, the loss is 0.385145
# Current epoch takes:  26.157999992370605
# -------Epoch 207 is finished.-------
# Epoch 208, the loss is 0.404831
# Current epoch takes:  26.4229998588562
# -------Epoch 208 is finished.-------
# Epoch 209, the loss is 0.465066
# Current epoch takes:  26.641000032424927
# -------Epoch 209 is finished.-------
# Epoch 210, the loss is 0.367745
# Current epoch takes:  26.499000072479248
# -------Epoch 210 is finished.-------
# Epoch 211, the loss is 0.407607
# Current epoch takes:  26.54800009727478
# -------Epoch 211 is finished.-------
# Epoch 212, the loss is 0.386293
# Current epoch takes:  26.50499987602234
# -------Epoch 212 is finished.-------
# Epoch 213, the loss is 0.375866
# Current epoch takes:  26.572999954223633
# -------Epoch 213 is finished.-------
# Epoch 214, the loss is 0.391794
# Current epoch takes:  26.407000064849854
# -------Epoch 214 is finished.-------
# Epoch 215, the loss is 0.370883
# Current epoch takes:  26.693000078201294
# -------Epoch 215 is finished.-------
# Epoch 216, the loss is 0.413433
# Current epoch takes:  26.477999925613403
# -------Epoch 216 is finished.-------
# Epoch 217, the loss is 0.369167
# Current epoch takes:  26.266000032424927
# -------Epoch 217 is finished.-------
# Epoch 218, the loss is 0.410462
# Current epoch takes:  26.31500005722046
# -------Epoch 218 is finished.-------
# Epoch 219, the loss is 0.371714
# Current epoch takes:  26.33899998664856
# -------Epoch 219 is finished.-------
# Epoch 220, the loss is 0.370046
# Current epoch takes:  26.578999996185303
# -------Epoch 220 is finished.-------
# Epoch 221, the loss is 0.368353
# Current epoch takes:  26.70899987220764
# -------Epoch 221 is finished.-------
# Epoch 222, the loss is 0.431016
# Current epoch takes:  26.253999948501587
# -------Epoch 222 is finished.-------
# Epoch 223, the loss is 0.385391
# Current epoch takes:  26.44000005722046
# -------Epoch 223 is finished.-------
# Epoch 224, the loss is 0.431200
# Current epoch takes:  26.499000072479248
# -------Epoch 224 is finished.-------
# Epoch 225, the loss is 0.397406
# Current epoch takes:  26.348999977111816
# -------Epoch 225 is finished.-------
# Epoch 226, the loss is 0.403625
# Current epoch takes:  26.32800006866455
# -------Epoch 226 is finished.-------
# Epoch 227, the loss is 0.378635
# Current epoch takes:  26.269999980926514
# -------Epoch 227 is finished.-------
# Epoch 228, the loss is 0.383758
# Current epoch takes:  26.46499991416931
# -------Epoch 228 is finished.-------
# Epoch 229, the loss is 0.403728
# Current epoch takes:  26.329999923706055
# -------Epoch 229 is finished.-------
# Epoch 230, the loss is 0.375554
# Current epoch takes:  26.21399998664856
# -------Epoch 230 is finished.-------
# Epoch 231, the loss is 0.385718
# Current epoch takes:  26.63100004196167
# -------Epoch 231 is finished.-------
# Epoch 232, the loss is 0.414099
# Current epoch takes:  26.241000175476074
# -------Epoch 232 is finished.-------
# Epoch 233, the loss is 0.397359
# Current epoch takes:  26.16099977493286
# -------Epoch 233 is finished.-------
# Epoch 234, the loss is 0.342012
# Current epoch takes:  26.278000116348267
# -------Epoch 234 is finished.-------
# Epoch 235, the loss is 0.376939
# Current epoch takes:  26.594000101089478
# -------Epoch 235 is finished.-------
# Epoch 236, the loss is 0.365315
# Current epoch takes:  26.322999954223633
# -------Epoch 236 is finished.-------
# Epoch 237, the loss is 0.347415
# Current epoch takes:  26.096999883651733
# -------Epoch 237 is finished.-------
# Epoch 238, the loss is 0.352546
# Current epoch takes:  26.103000164031982
# -------Epoch 238 is finished.-------
# Epoch 239, the loss is 0.389831
# Current epoch takes:  26.467999935150146
# -------Epoch 239 is finished.-------
# Epoch 240, the loss is 0.440902
# Current epoch takes:  26.36899995803833
# -------Epoch 240 is finished.-------
# Epoch 241, the loss is 0.488511
# Current epoch takes:  26.424999952316284
# -------Epoch 241 is finished.-------
# Epoch 242, the loss is 0.391207
# Current epoch takes:  26.365999937057495
# -------Epoch 242 is finished.-------
# Epoch 243, the loss is 0.434937
# Current epoch takes:  26.44100022315979
# -------Epoch 243 is finished.-------
# Epoch 244, the loss is 0.369337
# Current epoch takes:  26.524999856948853
# -------Epoch 244 is finished.-------
# Epoch 245, the loss is 0.415499
# Current epoch takes:  26.436000108718872
# -------Epoch 245 is finished.-------
# Epoch 246, the loss is 0.385353
# Current epoch takes:  26.38599991798401
# -------Epoch 246 is finished.-------
# Epoch 247, the loss is 0.393041
# Current epoch takes:  26.23099994659424
# -------Epoch 247 is finished.-------
# Epoch 248, the loss is 0.364635
# Current epoch takes:  26.09000015258789
# -------Epoch 248 is finished.-------
# Epoch 249, the loss is 0.352964
# Current epoch takes:  26.181999921798706
# -------Epoch 249 is finished.-------
# Epoch 250, the loss is 0.407336
# Current epoch takes:  26.223000049591064
# -------Epoch 250 is finished.-------
# Epoch 251, the loss is 0.393038
# Current epoch takes:  26.115000009536743
# -------Epoch 251 is finished.-------
# Epoch 252, the loss is 0.350303
# Current epoch takes:  26.296000003814697
# -------Epoch 252 is finished.-------
# Epoch 253, the loss is 0.383534
# Current epoch takes:  26.401000022888184
# -------Epoch 253 is finished.-------
# Epoch 254, the loss is 0.373436
# Current epoch takes:  26.187999963760376
# -------Epoch 254 is finished.-------
# Epoch 255, the loss is 0.424260
# Current epoch takes:  26.555999994277954
# -------Epoch 255 is finished.-------
# Epoch 256, the loss is 0.399182
# Current epoch takes:  26.177000045776367
# -------Epoch 256 is finished.-------
# Epoch 257, the loss is 0.404237
# Current epoch takes:  26.20199990272522
# -------Epoch 257 is finished.-------
# Epoch 258, the loss is 0.368226
# Current epoch takes:  26.191999912261963
# -------Epoch 258 is finished.-------
# Epoch 259, the loss is 0.397376
# Current epoch takes:  26.30900001525879
# -------Epoch 259 is finished.-------
# Epoch 260, the loss is 0.359885
# Current epoch takes:  26.294000148773193
# -------Epoch 260 is finished.-------
# Epoch 261, the loss is 0.410771
# Current epoch takes:  26.210000038146973
# -------Epoch 261 is finished.-------
# Epoch 262, the loss is 0.367291
# Current epoch takes:  26.155999898910522
# -------Epoch 262 is finished.-------
# Epoch 263, the loss is 0.363558
# Current epoch takes:  26.32200002670288
# -------Epoch 263 is finished.-------
# Epoch 264, the loss is 0.354036
# Current epoch takes:  26.299999952316284
# -------Epoch 264 is finished.-------
# Epoch 265, the loss is 0.374332
# Current epoch takes:  26.140000104904175
# -------Epoch 265 is finished.-------
# Epoch 266, the loss is 0.368350
# Current epoch takes:  26.47499990463257
# -------Epoch 266 is finished.-------
# Epoch 267, the loss is 0.391225
# Current epoch takes:  27.450000047683716
# -------Epoch 267 is finished.-------
# Epoch 268, the loss is 0.366452
# Current epoch takes:  26.363999843597412
# -------Epoch 268 is finished.-------
# Epoch 269, the loss is 0.353679
# Current epoch takes:  26.252000093460083
# -------Epoch 269 is finished.-------
# Epoch 270, the loss is 0.414250
# Current epoch takes:  26.374000072479248
# -------Epoch 270 is finished.-------
# Epoch 271, the loss is 0.401307
# Current epoch takes:  26.22000002861023
# -------Epoch 271 is finished.-------
# Epoch 272, the loss is 0.467819
# Current epoch takes:  26.13099980354309
# -------Epoch 272 is finished.-------
# Epoch 273, the loss is 0.366102
# Current epoch takes:  26.14400005340576
# -------Epoch 273 is finished.-------
# Epoch 274, the loss is 0.389141
# Current epoch takes:  26.170000076293945
# -------Epoch 274 is finished.-------
# Epoch 275, the loss is 0.349942
# Current epoch takes:  26.342999935150146
# -------Epoch 275 is finished.-------
# Epoch 276, the loss is 0.360373
# Current epoch takes:  26.32100009918213
# -------Epoch 276 is finished.-------
# Epoch 277, the loss is 0.420107
# Current epoch takes:  26.41100001335144
# -------Epoch 277 is finished.-------
# Epoch 278, the loss is 0.397781
# Current epoch takes:  26.537999868392944
# -------Epoch 278 is finished.-------
# Epoch 279, the loss is 0.365285
# Current epoch takes:  26.151999950408936
# -------Epoch 279 is finished.-------
# Epoch 280, the loss is 0.357981
# Current epoch takes:  26.118000030517578
# -------Epoch 280 is finished.-------
# Epoch 281, the loss is 0.352469
# Current epoch takes:  26.180999994277954
# -------Epoch 281 is finished.-------
# Epoch 282, the loss is 0.368339
# Current epoch takes:  26.22699999809265
# -------Epoch 282 is finished.-------
# Epoch 283, the loss is 0.433602
# Current epoch takes:  26.2020001411438
# -------Epoch 283 is finished.-------
# Epoch 284, the loss is 0.351749
# Current epoch takes:  26.30999994277954
# -------Epoch 284 is finished.-------
# Epoch 285, the loss is 0.410982
# Current epoch takes:  26.47000002861023
# -------Epoch 285 is finished.-------
# Epoch 286, the loss is 0.354027
# Current epoch takes:  26.25499987602234
# -------Epoch 286 is finished.-------
# Epoch 287, the loss is 0.455968
# Current epoch takes:  26.301000118255615
# -------Epoch 287 is finished.-------
# Epoch 288, the loss is 0.385048
# Current epoch takes:  26.198999881744385
# -------Epoch 288 is finished.-------
# Epoch 289, the loss is 0.390026
# Current epoch takes:  26.593000173568726
# -------Epoch 289 is finished.-------
# Epoch 290, the loss is 0.387163
# Current epoch takes:  26.4229998588562
# -------Epoch 290 is finished.-------
# Epoch 291, the loss is 0.354030
# Current epoch takes:  26.39800000190735
# -------Epoch 291 is finished.-------
# Epoch 292, the loss is 0.394249
# Current epoch takes:  26.193000078201294
# -------Epoch 292 is finished.-------
# Epoch 293, the loss is 0.346317
# Current epoch takes:  26.85800004005432
# -------Epoch 293 is finished.-------
# Epoch 294, the loss is 0.393557
# Current epoch takes:  26.335999965667725
# -------Epoch 294 is finished.-------
# Epoch 295, the loss is 0.368275
# Current epoch takes:  26.11400008201599
# -------Epoch 295 is finished.-------
# Epoch 296, the loss is 0.387129
# Current epoch takes:  26.31499981880188
# -------Epoch 296 is finished.-------
# Epoch 297, the loss is 0.344901
# Current epoch takes:  26.01200008392334
# -------Epoch 297 is finished.-------
# Epoch 298, the loss is 0.384647
# Current epoch takes:  26.466000080108643
# -------Epoch 298 is finished.-------
# Epoch 299, the loss is 0.361103
# Current epoch takes:  26.021999835968018
# -------Epoch 299 is finished.-------
# Epoch 300, the loss is 0.366500
# Current epoch takes:  26.20300006866455
# -------Epoch 300 is finished.-------
# Epoch 301, the loss is 0.362946
# Current epoch takes:  26.477999925613403
# -------Epoch 301 is finished.-------
# Epoch 302, the loss is 0.400420
# Current epoch takes:  26.042999982833862
# -------Epoch 302 is finished.-------
# Epoch 303, the loss is 0.428957
# Current epoch takes:  26.312000036239624
# -------Epoch 303 is finished.-------
# Epoch 304, the loss is 0.354838
# Current epoch takes:  26.37000012397766
# -------Epoch 304 is finished.-------
# Epoch 305, the loss is 0.371150
# Current epoch takes:  26.557999849319458
# -------Epoch 305 is finished.-------
# Epoch 306, the loss is 0.342858
# Current epoch takes:  26.373000144958496
# -------Epoch 306 is finished.-------
# Epoch 307, the loss is 0.334747
# Current epoch takes:  26.003000020980835
# -------Epoch 307 is finished.-------
# Epoch 308, the loss is 0.335777
# Current epoch takes:  26.585000038146973
# -------Epoch 308 is finished.-------
# Epoch 309, the loss is 0.379185
# Current epoch takes:  26.357999801635742
# -------Epoch 309 is finished.-------
# Epoch 310, the loss is 0.393865
# Current epoch takes:  26.013000011444092
# -------Epoch 310 is finished.-------
# Epoch 311, the loss is 0.392115
# Current epoch takes:  26.59000015258789
# -------Epoch 311 is finished.-------
# Epoch 312, the loss is 0.382437
# Current epoch takes:  26.560999870300293
# -------Epoch 312 is finished.-------
# Epoch 313, the loss is 0.386794
# Current epoch takes:  26.597000122070312
# -------Epoch 313 is finished.-------
# Epoch 314, the loss is 0.396040
# Current epoch takes:  26.592999935150146
# -------Epoch 314 is finished.-------
# Epoch 315, the loss is 0.360784
# Current epoch takes:  26.484999895095825
# -------Epoch 315 is finished.-------
# Epoch 316, the loss is 0.392951
# Current epoch takes:  25.98900008201599
# -------Epoch 316 is finished.-------
# Epoch 317, the loss is 0.402402
# Current epoch takes:  26.331000089645386
# -------Epoch 317 is finished.-------
# Epoch 318, the loss is 0.401372
# Current epoch takes:  26.453999996185303
# -------Epoch 318 is finished.-------
# Epoch 319, the loss is 0.353544
# Current epoch takes:  26.217000007629395
# -------Epoch 319 is finished.-------
# Epoch 320, the loss is 0.376387
# Current epoch takes:  26.52899980545044
# -------Epoch 320 is finished.-------
# Epoch 321, the loss is 0.374469
# Current epoch takes:  26.31000018119812
# -------Epoch 321 is finished.-------
# Epoch 322, the loss is 0.365114
# Current epoch takes:  26.181999921798706
# -------Epoch 322 is finished.-------
# Epoch 323, the loss is 0.367866
# Current epoch takes:  26.48900008201599
# -------Epoch 323 is finished.-------
# Epoch 324, the loss is 0.370580
# Current epoch takes:  26.590999841690063
# -------Epoch 324 is finished.-------
# Epoch 325, the loss is 0.354433
# Current epoch takes:  26.386000156402588
# -------Epoch 325 is finished.-------
# Epoch 326, the loss is 0.343511
# Current epoch takes:  25.99899983406067
# -------Epoch 326 is finished.-------
# Epoch 327, the loss is 0.456649
# Current epoch takes:  26.301000118255615
# -------Epoch 327 is finished.-------
# Epoch 328, the loss is 0.345518
# Current epoch takes:  26.582000017166138
# -------Epoch 328 is finished.-------
# Epoch 329, the loss is 0.392090
# Current epoch takes:  26.033999919891357
# -------Epoch 329 is finished.-------
# Epoch 330, the loss is 0.491688
# Current epoch takes:  26.01900005340576
# -------Epoch 330 is finished.-------
# Epoch 331, the loss is 0.355436
# Current epoch takes:  26.134999990463257
# -------Epoch 331 is finished.-------
# Epoch 332, the loss is 0.400320
# Current epoch takes:  26.52999997138977
# -------Epoch 332 is finished.-------
# Epoch 333, the loss is 0.407700
# Current epoch takes:  26.456000089645386
# -------Epoch 333 is finished.-------
# Epoch 334, the loss is 0.389086
# Current epoch takes:  26.520999908447266
# -------Epoch 334 is finished.-------
# Epoch 335, the loss is 0.355919
# Current epoch takes:  26.831000089645386
# -------Epoch 335 is finished.-------
# Epoch 336, the loss is 0.359180
# Current epoch takes:  26.11299991607666
# -------Epoch 336 is finished.-------
# Epoch 337, the loss is 0.380638
# Current epoch takes:  26.40400004386902
# -------Epoch 337 is finished.-------
# Epoch 338, the loss is 0.336378
# Current epoch takes:  26.575999975204468
# -------Epoch 338 is finished.-------
# Epoch 339, the loss is 0.368214
# Current epoch takes:  26.454999923706055
# -------Epoch 339 is finished.-------
# Epoch 340, the loss is 0.362414
# Current epoch takes:  26.342000007629395
# -------Epoch 340 is finished.-------
# Epoch 341, the loss is 0.401241
# Current epoch takes:  26.483999967575073
# -------Epoch 341 is finished.-------
# Epoch 342, the loss is 0.403921
# Current epoch takes:  26.448000192642212
# -------Epoch 342 is finished.-------
# Epoch 343, the loss is 0.403958
# Current epoch takes:  26.363999843597412
# -------Epoch 343 is finished.-------
# Epoch 344, the loss is 0.338734
# Current epoch takes:  26.22099995613098
# -------Epoch 344 is finished.-------
# Epoch 345, the loss is 0.365732
# Current epoch takes:  26.52900004386902
# -------Epoch 345 is finished.-------
# Epoch 346, the loss is 0.384298
# Current epoch takes:  26.141000032424927
# -------Epoch 346 is finished.-------
# Epoch 347, the loss is 0.357225
# Current epoch takes:  26.14300012588501
# -------Epoch 347 is finished.-------
# Epoch 348, the loss is 0.320319
# Current epoch takes:  26.526000022888184
# -------Epoch 348 is finished.-------
# Epoch 349, the loss is 0.357893
# Current epoch takes:  26.4229998588562
# -------Epoch 349 is finished.-------
# Epoch 350, the loss is 0.398589
# Current epoch takes:  26.16700005531311
# -------Epoch 350 is finished.-------
# Epoch 351, the loss is 0.400015
# Current epoch takes:  25.996000051498413
# -------Epoch 351 is finished.-------
# Epoch 352, the loss is 0.441376
# Current epoch takes:  26.478999853134155
# -------Epoch 352 is finished.-------
# Epoch 353, the loss is 0.368566
# Current epoch takes:  26.502000093460083
# -------Epoch 353 is finished.-------
# Epoch 354, the loss is 0.366569
# Current epoch takes:  26.335999965667725
# -------Epoch 354 is finished.-------
# Epoch 355, the loss is 0.371661
# Current epoch takes:  26.27500009536743
# -------Epoch 355 is finished.-------
# Epoch 356, the loss is 0.346134
# Current epoch takes:  26.306999921798706
# -------Epoch 356 is finished.-------
# Epoch 357, the loss is 0.366052
# Current epoch takes:  26.52900004386902
# -------Epoch 357 is finished.-------
# Epoch 358, the loss is 0.398376
# Current epoch takes:  26.310999870300293
# -------Epoch 358 is finished.-------
# Epoch 359, the loss is 0.358553
# Current epoch takes:  26.542999982833862
# -------Epoch 359 is finished.-------
# Epoch 360, the loss is 0.361574
# Current epoch takes:  26.605000019073486
# -------Epoch 360 is finished.-------
# Epoch 361, the loss is 0.441343
# Current epoch takes:  26.27500009536743
# -------Epoch 361 is finished.-------
# Epoch 362, the loss is 0.412837
# Current epoch takes:  26.417999982833862
# -------Epoch 362 is finished.-------
# Epoch 363, the loss is 0.389688
# Current epoch takes:  26.58299994468689
# -------Epoch 363 is finished.-------
# Epoch 364, the loss is 0.399285
# Current epoch takes:  26.0
# -------Epoch 364 is finished.-------
# Epoch 365, the loss is 0.370236
# Current epoch takes:  26.272000074386597
# -------Epoch 365 is finished.-------
# Epoch 366, the loss is 0.345932
# Current epoch takes:  26.374000072479248
# -------Epoch 366 is finished.-------
# Epoch 367, the loss is 0.353823
# Current epoch takes:  26.48199987411499
# -------Epoch 367 is finished.-------
# Epoch 368, the loss is 0.404905
# Current epoch takes:  26.42199993133545
# -------Epoch 368 is finished.-------
# Epoch 369, the loss is 0.364218
# Current epoch takes:  26.145000219345093
# -------Epoch 369 is finished.-------
# Epoch 370, the loss is 0.382674
# Current epoch takes:  26.447999954223633
# -------Epoch 370 is finished.-------
# Epoch 371, the loss is 0.362428
# Current epoch takes:  26.453999996185303
# -------Epoch 371 is finished.-------
# Epoch 372, the loss is 0.349018
# Current epoch takes:  26.378999948501587
# -------Epoch 372 is finished.-------
# Epoch 373, the loss is 0.413199
# Current epoch takes:  26.13599991798401
# -------Epoch 373 is finished.-------
# Epoch 374, the loss is 0.400611
# Current epoch takes:  26.403000116348267
# -------Epoch 374 is finished.-------
# Epoch 375, the loss is 0.380290
# Current epoch takes:  26.657000064849854
# -------Epoch 375 is finished.-------
# Epoch 376, the loss is 0.469285
# Current epoch takes:  26.482999801635742
# -------Epoch 376 is finished.-------
# Epoch 377, the loss is 0.394234
# Current epoch takes:  26.384000062942505
# -------Epoch 377 is finished.-------
# Epoch 378, the loss is 0.405882
# Current epoch takes:  26.270999908447266
# -------Epoch 378 is finished.-------
# Epoch 379, the loss is 0.384005
# Current epoch takes:  26.641000032424927
# -------Epoch 379 is finished.-------
# Epoch 380, the loss is 0.396831
# Current epoch takes:  26.381999969482422
# -------Epoch 380 is finished.-------
# Epoch 381, the loss is 0.425888
# Current epoch takes:  26.47699999809265
# -------Epoch 381 is finished.-------
# Epoch 382, the loss is 0.329963
# Current epoch takes:  26.544000148773193
# -------Epoch 382 is finished.-------
# Epoch 383, the loss is 0.394479
# Current epoch takes:  26.723000049591064
# -------Epoch 383 is finished.-------
# Epoch 384, the loss is 0.415970
# Current epoch takes:  26.48199987411499
# -------Epoch 384 is finished.-------
# Epoch 385, the loss is 0.374532
# Current epoch takes:  26.671000003814697
# -------Epoch 385 is finished.-------
# Epoch 386, the loss is 0.414939
# Current epoch takes:  26.503999948501587
# -------Epoch 386 is finished.-------
# Epoch 387, the loss is 0.389943
# Current epoch takes:  26.271000146865845
# -------Epoch 387 is finished.-------
# Epoch 388, the loss is 0.394582
# Current epoch takes:  26.300999879837036
# -------Epoch 388 is finished.-------
# Epoch 389, the loss is 0.416652
# Current epoch takes:  26.48300004005432
# -------Epoch 389 is finished.-------
# Epoch 390, the loss is 0.390951
# Current epoch takes:  26.67300009727478
# -------Epoch 390 is finished.-------
# Epoch 391, the loss is 0.371696
# Current epoch takes:  26.27900004386902
# -------Epoch 391 is finished.-------
# Epoch 392, the loss is 0.405629
# Current epoch takes:  26.38699984550476
# -------Epoch 392 is finished.-------
# Epoch 393, the loss is 0.432477
# Current epoch takes:  26.186000108718872
# -------Epoch 393 is finished.-------
# Epoch 394, the loss is 0.380728
# Current epoch takes:  26.194999933242798
# -------Epoch 394 is finished.-------
# Epoch 395, the loss is 0.395588
# Current epoch takes:  26.276999950408936
# -------Epoch 395 is finished.-------
# Epoch 396, the loss is 0.354302
# Current epoch takes:  26.48300004005432
# -------Epoch 396 is finished.-------
# Epoch 397, the loss is 0.350505
# Current epoch takes:  26.59500002861023
# -------Epoch 397 is finished.-------
# Epoch 398, the loss is 0.408797
# Current epoch takes:  26.236000061035156
# -------Epoch 398 is finished.-------
# Epoch 399, the loss is 0.355698
# Current epoch takes:  26.47599983215332
# -------Epoch 399 is finished.-------
# Epoch 400, the loss is 0.427369
# Current epoch takes:  26.450999975204468
# -------Epoch 400 is finished.-------
# Epoch 401, the loss is 0.423794
# Current epoch takes:  26.455000162124634
# -------Epoch 401 is finished.-------
# Epoch 402, the loss is 0.336798
# Current epoch takes:  26.217999935150146
# -------Epoch 402 is finished.-------
# Epoch 403, the loss is 0.370919
# Current epoch takes:  27.1010000705719
# -------Epoch 403 is finished.-------
# Epoch 404, the loss is 0.358727
# Current epoch takes:  26.72000002861023
# -------Epoch 404 is finished.-------
# Epoch 405, the loss is 0.365568
# Current epoch takes:  26.245999813079834
# -------Epoch 405 is finished.-------
# Epoch 406, the loss is 0.370607
# Current epoch takes:  26.212000131607056
# -------Epoch 406 is finished.-------
# Epoch 407, the loss is 0.349706
# Current epoch takes:  26.455999851226807
# -------Epoch 407 is finished.-------
# Epoch 408, the loss is 0.351292
# Current epoch takes:  26.139000177383423
# -------Epoch 408 is finished.-------
# Epoch 409, the loss is 0.360775
# Current epoch takes:  25.97599983215332
# -------Epoch 409 is finished.-------
# Epoch 410, the loss is 0.377349
# Current epoch takes:  26.409000158309937
# -------Epoch 410 is finished.-------
# Epoch 411, the loss is 0.387255
# Current epoch takes:  26.592000007629395
# -------Epoch 411 is finished.-------
# Epoch 412, the loss is 0.399317
# Current epoch takes:  26.35599994659424
# -------Epoch 412 is finished.-------
# Epoch 413, the loss is 0.369355
# Current epoch takes:  26.617000102996826
# -------Epoch 413 is finished.-------
# Epoch 414, the loss is 0.401675
# Current epoch takes:  26.423999786376953
# -------Epoch 414 is finished.-------
# Epoch 415, the loss is 0.383636
# Current epoch takes:  26.271000146865845
# -------Epoch 415 is finished.-------
# Epoch 416, the loss is 0.347820
# Current epoch takes:  26.236999988555908
# -------Epoch 416 is finished.-------
# Epoch 417, the loss is 0.340984
# Current epoch takes:  26.55399990081787
# -------Epoch 417 is finished.-------
# Epoch 418, the loss is 0.402487
# Current epoch takes:  26.269999980926514
# -------Epoch 418 is finished.-------
# Epoch 419, the loss is 0.354490
# Current epoch takes:  26.42900013923645
# -------Epoch 419 is finished.-------
# Epoch 420, the loss is 0.372533
# Current epoch takes:  26.30999994277954
# -------Epoch 420 is finished.-------
# Epoch 421, the loss is 0.368698
# Current epoch takes:  26.42199993133545
# -------Epoch 421 is finished.-------
# Epoch 422, the loss is 0.392319
# Current epoch takes:  26.217000007629395
# -------Epoch 422 is finished.-------
# Epoch 423, the loss is 0.352782
# Current epoch takes:  26.151000022888184
# -------Epoch 423 is finished.-------
# Epoch 424, the loss is 0.388665
# Current epoch takes:  26.153000116348267
# -------Epoch 424 is finished.-------
# Epoch 425, the loss is 0.371187
# Current epoch takes:  26.256999969482422
# -------Epoch 425 is finished.-------
# Epoch 426, the loss is 0.390615
# Current epoch takes:  26.228999853134155
# -------Epoch 426 is finished.-------
# Epoch 427, the loss is 0.378443
# Current epoch takes:  26.407999992370605
# -------Epoch 427 is finished.-------
# Epoch 428, the loss is 0.379928
# Current epoch takes:  26.217000007629395
# -------Epoch 428 is finished.-------
# Epoch 429, the loss is 0.387072
# Current epoch takes:  26.27300000190735
# -------Epoch 429 is finished.-------
# Epoch 430, the loss is 0.345582
# Current epoch takes:  26.377000093460083
# -------Epoch 430 is finished.-------
# Epoch 431, the loss is 0.389768
# Current epoch takes:  26.08999991416931
# -------Epoch 431 is finished.-------
# Epoch 432, the loss is 0.409512
# Current epoch takes:  26.110000133514404
# -------Epoch 432 is finished.-------
# Epoch 433, the loss is 0.398501
# Current epoch takes:  26.082000017166138
# -------Epoch 433 is finished.-------
# Epoch 434, the loss is 0.348524
# Current epoch takes:  26.185999870300293
# -------Epoch 434 is finished.-------
# Epoch 435, the loss is 0.337862
# Current epoch takes:  26.3510000705719
# -------Epoch 435 is finished.-------
# Epoch 436, the loss is 0.423089
# Current epoch takes:  26.094000101089478
# -------Epoch 436 is finished.-------
# Epoch 437, the loss is 0.412576
# Current epoch takes:  26.27899980545044
# -------Epoch 437 is finished.-------
# Epoch 438, the loss is 0.345811
# Current epoch takes:  26.380000114440918
# -------Epoch 438 is finished.-------
# ...
# -------Epoch 854 is finished.-------
# Epoch 855, the loss is 0.435593
# Current epoch takes:  26.58999991416931
# -------Epoch 855 is finished.-------
# Epoch 856, the loss is 0.398751
# Current epoch takes:  26.710000038146973
# -------Epoch 856 is finished.-------
# Epoch 857, the loss is 0.373764
# Current epoch takes:  28.12000012397766
# -------Epoch 857 is finished.-------
# Epoch 858, the loss is 0.374943
# Current epoch takes:  28.02999997138977
# -------Epoch 858 is finished.-------
# Epoch 859, the loss is 0.340884
# Current epoch takes:  26.80900001525879
# -------Epoch 859 is finished.-------
# Epoch 860, the loss is 0.383194
# Current epoch takes:  27.746999979019165
# -------Epoch 860 is finished.-------
# Epoch 861, the loss is 0.364177
# Current epoch takes:  27.953999996185303
# -------Epoch 861 is finished.-------
# Epoch 862, the loss is 0.375680
# Current epoch takes:  28.026999950408936
# -------Epoch 862 is finished.-------
# Epoch 863, the loss is 0.359790
# Current epoch takes:  27.97099995613098
# -------Epoch 863 is finished.-------
# Epoch 864, the loss is 0.353301
# Current epoch takes:  26.252000093460083
# -------Epoch 864 is finished.-------
# Epoch 865, the loss is 0.383404
# Current epoch takes:  28.098000049591064
# -------Epoch 865 is finished.-------
# Epoch 866, the loss is 0.361674
# Current epoch takes:  27.90999984741211
# -------Epoch 866 is finished.-------
# Epoch 867, the loss is 0.343425
# Current epoch takes:  26.83299994468689
# -------Epoch 867 is finished.-------
# Epoch 868, the loss is 0.386274
# Current epoch takes:  26.277000188827515
# -------Epoch 868 is finished.-------
# Epoch 869, the loss is 0.366791
# Current epoch takes:  27.950999975204468
# -------Epoch 869 is finished.-------
# Epoch 870, the loss is 0.355207
# Current epoch takes:  26.360999822616577
# -------Epoch 870 is finished.-------
# Epoch 871, the loss is 0.335553
# Current epoch takes:  26.503000020980835
# -------Epoch 871 is finished.-------
# Epoch 872, the loss is 0.407492
# Current epoch takes:  26.651000022888184
# -------Epoch 872 is finished.-------
# Epoch 873, the loss is 0.356007
# Current epoch takes:  26.50100016593933
# -------Epoch 873 is finished.-------
# Epoch 874, the loss is 0.376131
# Current epoch takes:  26.198999881744385
# -------Epoch 874 is finished.-------
# Epoch 875, the loss is 0.359830
# Current epoch takes:  26.782000064849854
# -------Epoch 875 is finished.-------
# Epoch 876, the loss is 0.326890
# Current epoch takes:  26.62999987602234
# -------Epoch 876 is finished.-------
# Epoch 877, the loss is 0.388840
# Current epoch takes:  26.652000188827515
# -------Epoch 877 is finished.-------
# Epoch 878, the loss is 0.362670
# Current epoch takes:  27.84599995613098
# -------Epoch 878 is finished.-------
# Epoch 879, the loss is 0.346455
# Current epoch takes:  26.45899987220764
# -------Epoch 879 is finished.-------
# Epoch 880, the loss is 0.342450
# Current epoch takes:  26.76200008392334
# -------Epoch 880 is finished.-------
# Epoch 881, the loss is 0.326586
# Current epoch takes:  26.543999910354614
# -------Epoch 881 is finished.-------
# Epoch 882, the loss is 0.409855
# Current epoch takes:  26.633000135421753
# -------Epoch 882 is finished.-------
# Epoch 883, the loss is 0.351757
# Current epoch takes:  28.039999961853027
# -------Epoch 883 is finished.-------
# Epoch 884, the loss is 0.364865
# Current epoch takes:  26.425999879837036
# -------Epoch 884 is finished.-------
# Epoch 885, the loss is 0.328073
# Current epoch takes:  26.574000120162964
# -------Epoch 885 is finished.-------
# Epoch 886, the loss is 0.355795
# Current epoch takes:  27.920000076293945
# -------Epoch 886 is finished.-------
# Epoch 887, the loss is 0.383402
# Current epoch takes:  27.965999841690063
# -------Epoch 887 is finished.-------
# Epoch 888, the loss is 0.387020
# Current epoch takes:  26.248000144958496
# -------Epoch 888 is finished.-------
# Epoch 889, the loss is 0.346392
# Current epoch takes:  27.997999906539917
# -------Epoch 889 is finished.-------
# Epoch 890, the loss is 0.377811
# Current epoch takes:  27.980000019073486
# -------Epoch 890 is finished.-------
# Epoch 891, the loss is 0.327452
# Current epoch takes:  27.875
# -------Epoch 891 is finished.-------
# Epoch 892, the loss is 0.388374
# Current epoch takes:  26.25600004196167
# -------Epoch 892 is finished.-------
# Epoch 893, the loss is 0.345738
# Current epoch takes:  26.258999824523926
# -------Epoch 893 is finished.-------
# Epoch 894, the loss is 0.365097
# Current epoch takes:  26.5
# -------Epoch 894 is finished.-------
# Epoch 895, the loss is 0.367914
# Current epoch takes:  26.814000129699707
# -------Epoch 895 is finished.-------
# Epoch 896, the loss is 0.344058
# Current epoch takes:  28.003999948501587
# -------Epoch 896 is finished.-------
# Epoch 897, the loss is 0.349443
# Current epoch takes:  27.93400001525879
# -------Epoch 897 is finished.-------
# Epoch 898, the loss is 0.346868
# Current epoch takes:  28.028000116348267
# -------Epoch 898 is finished.-------
# Epoch 899, the loss is 0.354935
# Current epoch takes:  28.019999980926514
# -------Epoch 899 is finished.-------
# Epoch 900, the loss is 0.393545
# Current epoch takes:  28.014999866485596
# -------Epoch 900 is finished.-------
# Epoch 901, the loss is 0.377731
# Current epoch takes:  27.200999975204468
# -------Epoch 901 is finished.-------
# Epoch 902, the loss is 0.362702
# Current epoch takes:  28.11300015449524
# -------Epoch 902 is finished.-------
# Epoch 903, the loss is 0.377367
# Current epoch takes:  27.950999975204468
# -------Epoch 903 is finished.-------
# Epoch 904, the loss is 0.357598
# Current epoch takes:  28.08899998664856
# -------Epoch 904 is finished.-------
# Epoch 905, the loss is 0.390086
# Current epoch takes:  27.98900008201599
# -------Epoch 905 is finished.-------
# Epoch 906, the loss is 0.343537
# Current epoch takes:  27.205999851226807
# -------Epoch 906 is finished.-------
# Epoch 907, the loss is 0.343943
# Current epoch takes:  27.942000150680542
# -------Epoch 907 is finished.-------
# Epoch 908, the loss is 0.356373
# Current epoch takes:  27.860999822616577
# -------Epoch 908 is finished.-------
# Epoch 909, the loss is 0.338591
# Current epoch takes:  26.60800004005432
# -------Epoch 909 is finished.-------
# Epoch 910, the loss is 0.385032
# Current epoch takes:  26.27300000190735
# -------Epoch 910 is finished.-------
# Epoch 911, the loss is 0.356984
# Current epoch takes:  28.09500002861023
# -------Epoch 911 is finished.-------
# Epoch 912, the loss is 0.339695
# Current epoch takes:  27.98300004005432
# -------Epoch 912 is finished.-------
# Epoch 913, the loss is 0.352111
# Current epoch takes:  27.882999897003174
# -------Epoch 913 is finished.-------
# Epoch 914, the loss is 0.332365
# Current epoch takes:  27.87600016593933
# -------Epoch 914 is finished.-------
# Epoch 915, the loss is 0.362750
# Current epoch takes:  26.631999969482422
# -------Epoch 915 is finished.-------
# Epoch 916, the loss is 0.373153
# Current epoch takes:  26.569999933242798
# -------Epoch 916 is finished.-------
# Epoch 917, the loss is 0.353900
# Current epoch takes:  28.13700008392334
# -------Epoch 917 is finished.-------
# Epoch 918, the loss is 0.355906
# Current epoch takes:  28.04099988937378
# -------Epoch 918 is finished.-------
# Epoch 919, the loss is 0.363360
# Current epoch takes:  28.10199999809265
# -------Epoch 919 is finished.-------
# Epoch 920, the loss is 0.388977
# Current epoch takes:  27.949000120162964
# -------Epoch 920 is finished.-------
# Epoch 921, the loss is 0.347470
# Current epoch takes:  28.015999794006348
# -------Epoch 921 is finished.-------
# Epoch 922, the loss is 0.373004
# Current epoch takes:  27.99500012397766
# -------Epoch 922 is finished.-------
# Epoch 923, the loss is 0.387046
# Current epoch takes:  28.171000003814697
# -------Epoch 923 is finished.-------
# Epoch 924, the loss is 0.350972
# Current epoch takes:  27.95799994468689
# -------Epoch 924 is finished.-------
# Epoch 925, the loss is 0.376488
# Current epoch takes:  28.193000078201294
# -------Epoch 925 is finished.-------
# Epoch 926, the loss is 0.352349
# Current epoch takes:  26.37999987602234
# -------Epoch 926 is finished.-------
# Epoch 927, the loss is 0.350688
# Current epoch takes:  26.526000022888184
# -------Epoch 927 is finished.-------
# Epoch 928, the loss is 0.371199
# Current epoch takes:  26.325000047683716
# -------Epoch 928 is finished.-------
# Epoch 929, the loss is 0.359800
# Current epoch takes:  26.61299991607666
# -------Epoch 929 is finished.-------
# Epoch 930, the loss is 0.363066
# Current epoch takes:  26.390000104904175
# -------Epoch 930 is finished.-------
# Epoch 931, the loss is 0.401740
# Current epoch takes:  28.11299991607666
# -------Epoch 931 is finished.-------
# Epoch 932, the loss is 0.353851
# Current epoch takes:  27.90400004386902
# -------Epoch 932 is finished.-------
# Epoch 933, the loss is 0.337791
# Current epoch takes:  27.944999933242798
# -------Epoch 933 is finished.-------
# Epoch 934, the loss is 0.387893
# Current epoch takes:  27.973000049591064
# -------Epoch 934 is finished.-------
# Epoch 935, the loss is 0.369475
# Current epoch takes:  27.98800015449524
# -------Epoch 935 is finished.-------
# Epoch 936, the loss is 0.389176
# Current epoch takes:  26.43999981880188
# -------Epoch 936 is finished.-------
# Epoch 937, the loss is 0.348371
# Current epoch takes:  26.914999961853027
# -------Epoch 937 is finished.-------
# Epoch 938, the loss is 0.358907
# Current epoch takes:  27.427000045776367
# -------Epoch 938 is finished.-------
# Epoch 939, the loss is 0.326522
# Current epoch takes:  26.447999954223633
# -------Epoch 939 is finished.-------
# Epoch 940, the loss is 0.347666
# Current epoch takes:  26.511000156402588
# -------Epoch 940 is finished.-------
# Epoch 941, the loss is 0.360739
# Current epoch takes:  26.65499997138977
# -------Epoch 941 is finished.-------
# Epoch 942, the loss is 0.341837
# Current epoch takes:  26.369999885559082
# -------Epoch 942 is finished.-------
# Epoch 943, the loss is 0.358880
# Current epoch takes:  26.695000171661377
# -------Epoch 943 is finished.-------
# Epoch 944, the loss is 0.344308
# Current epoch takes:  26.391000032424927
# -------Epoch 944 is finished.-------
# Epoch 945, the loss is 0.332052
# Current epoch takes:  26.288999795913696
# -------Epoch 945 is finished.-------
# Epoch 946, the loss is 0.344731
# Current epoch takes:  28.12600016593933
# -------Epoch 946 is finished.-------
# Epoch 947, the loss is 0.379635
# Current epoch takes:  26.25599980354309
# -------Epoch 947 is finished.-------
# Epoch 948, the loss is 0.354285
# Current epoch takes:  27.90500020980835
# -------Epoch 948 is finished.-------
# Epoch 949, the loss is 0.368274
# Current epoch takes:  27.94700002670288
# -------Epoch 949 is finished.-------
# Epoch 950, the loss is 0.417806
# Current epoch takes:  26.45699977874756
# -------Epoch 950 is finished.-------
# Epoch 951, the loss is 0.338453
# Current epoch takes:  26.502000093460083
# -------Epoch 951 is finished.-------
# Epoch 952, the loss is 0.362581
# Current epoch takes:  26.615999937057495
# -------Epoch 952 is finished.-------
# Epoch 953, the loss is 0.351570
# Current epoch takes:  28.011000156402588
# -------Epoch 953 is finished.-------
# Epoch 954, the loss is 0.339179
# Current epoch takes:  26.322999954223633
# -------Epoch 954 is finished.-------
# Epoch 955, the loss is 0.339441
# Current epoch takes:  26.424999952316284
# -------Epoch 955 is finished.-------
# Epoch 956, the loss is 0.350485
# Current epoch takes:  26.55299997329712
# -------Epoch 956 is finished.-------
# Epoch 957, the loss is 0.330962
# Current epoch takes:  26.67300009727478
# -------Epoch 957 is finished.-------
# Epoch 958, the loss is 0.358660
# Current epoch takes:  26.448999881744385
# -------Epoch 958 is finished.-------
# Epoch 959, the loss is 0.351184
# Current epoch takes:  26.901999950408936
# -------Epoch 959 is finished.-------
# Epoch 960, the loss is 0.370686
# Current epoch takes:  26.325000047683716
# -------Epoch 960 is finished.-------
# Epoch 961, the loss is 0.406252
# Current epoch takes:  28.153000116348267
# -------Epoch 961 is finished.-------
# Epoch 962, the loss is 0.371217
# Current epoch takes:  28.14800000190735
# -------Epoch 962 is finished.-------
# Epoch 963, the loss is 0.416862
# Current epoch takes:  26.253999948501587
# -------Epoch 963 is finished.-------
# Epoch 964, the loss is 0.379152
# Current epoch takes:  26.29200005531311
# -------Epoch 964 is finished.-------
# Epoch 965, the loss is 0.366807
# Current epoch takes:  26.2189998626709
# -------Epoch 965 is finished.-------
# Epoch 966, the loss is 0.398843
# Current epoch takes:  28.134999990463257
# -------Epoch 966 is finished.-------
# Epoch 967, the loss is 0.362709
# Current epoch takes:  27.98300004005432
# -------Epoch 967 is finished.-------
# Epoch 968, the loss is 0.365807
# Current epoch takes:  28.02900004386902
# -------Epoch 968 is finished.-------
# Epoch 969, the loss is 0.355467
# Current epoch takes:  26.344000101089478
# -------Epoch 969 is finished.-------
# Epoch 970, the loss is 0.348212
# Current epoch takes:  28.134999990463257
# -------Epoch 970 is finished.-------
# Epoch 971, the loss is 0.383898
# Current epoch takes:  26.240999937057495
# -------Epoch 971 is finished.-------
# Epoch 972, the loss is 0.344299
# Current epoch takes:  27.92799997329712
# -------Epoch 972 is finished.-------
# Epoch 973, the loss is 0.385925
# Current epoch takes:  27.875999927520752
# -------Epoch 973 is finished.-------
# Epoch 974, the loss is 0.371955
# Current epoch takes:  26.837000131607056
# -------Epoch 974 is finished.-------
# Epoch 975, the loss is 0.347070
# Current epoch takes:  27.96399998664856
# -------Epoch 975 is finished.-------
# Epoch 976, the loss is 0.400302
# Current epoch takes:  26.710000038146973
# -------Epoch 976 is finished.-------
# Epoch 977, the loss is 0.347018
# Current epoch takes:  26.243000030517578
# -------Epoch 977 is finished.-------
# Epoch 978, the loss is 0.339145
# Current epoch takes:  27.859999895095825
# -------Epoch 978 is finished.-------
# Epoch 979, the loss is 0.330009
# Current epoch takes:  27.973999977111816
# -------Epoch 979 is finished.-------
# Epoch 980, the loss is 0.342315
# Current epoch takes:  28.04800009727478
# -------Epoch 980 is finished.-------
# Epoch 981, the loss is 0.445561
# Current epoch takes:  27.342999935150146
# -------Epoch 981 is finished.-------
# Epoch 982, the loss is 0.386807
# Current epoch takes:  26.792999982833862
# -------Epoch 982 is finished.-------
# Epoch 983, the loss is 0.409166
# Current epoch takes:  28.187000036239624
# -------Epoch 983 is finished.-------
# Epoch 984, the loss is 0.376492
# Current epoch takes:  27.950999975204468
# -------Epoch 984 is finished.-------
# Epoch 985, the loss is 0.326377
# Current epoch takes:  27.990000009536743
# -------Epoch 985 is finished.-------
# Epoch 986, the loss is 0.428378
# Current epoch takes:  27.94599986076355
# -------Epoch 986 is finished.-------
# Epoch 987, the loss is 0.355074
# Current epoch takes:  27.985000133514404
# -------Epoch 987 is finished.-------
# Epoch 988, the loss is 0.368391
# Current epoch takes:  26.81599998474121
# -------Epoch 988 is finished.-------
# Epoch 989, the loss is 0.413951
# Current epoch takes:  27.973000049591064
# -------Epoch 989 is finished.-------
# Epoch 990, the loss is 0.359207
# Current epoch takes:  28.003999948501587
# -------Epoch 990 is finished.-------
# Epoch 991, the loss is 0.329276
# Current epoch takes:  28.157999992370605
# -------Epoch 991 is finished.-------
# Epoch 992, the loss is 0.374864
# Current epoch takes:  28.00600004196167
# -------Epoch 992 is finished.-------
# Epoch 993, the loss is 0.365363
# Current epoch takes:  26.378000020980835
# -------Epoch 993 is finished.-------
# Epoch 994, the loss is 0.410117
# Current epoch takes:  27.994999885559082
# -------Epoch 994 is finished.-------
# Epoch 995, the loss is 0.400484
# Current epoch takes:  27.980000019073486
# -------Epoch 995 is finished.-------
# Epoch 996, the loss is 0.352682
# Current epoch takes:  27.98900008201599
# -------Epoch 996 is finished.-------
# Epoch 997, the loss is 0.369057
# Current epoch takes:  28.10800004005432
# -------Epoch 997 is finished.-------
# Epoch 998, the loss is 0.351750
# Current epoch takes:  28.009999990463257
# -------Epoch 998 is finished.-------
# Epoch 999, the loss is 0.329709
# Current epoch takes:  28.14299988746643
# -------Epoch 999 is finished.-------
# Optimization Finished.
# The train process takes: 26857.99
